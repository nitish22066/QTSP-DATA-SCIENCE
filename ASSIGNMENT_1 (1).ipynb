# %% [markdown]
# # Apple Stock

# %% [markdown]
# ### Introduction:
#
# We are going to use Apple's stock price.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-902ffa3a-3f60-4027-84a0-df7f32eeff98" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-902ffa3a-3f60-4027-84a0-df7f32eeff98">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving appl_1980_2014.csv to appl_1980_2014 (2).csv

# %% [markdown]
# ### Step 3. Assign it to a variable apple

# %%
apple=pd.read_csv('appl_1980_2014.csv')
apple
# Out:
#             Date    Open    High     Low   Close     Volume  Adj Close
# 0     2014-07-08   96.27   96.80   93.92   95.35   65130000      95.35
# 1     2014-07-07   94.14   95.99   94.10   95.97   56305400      95.97
# 2     2014-07-03   93.67   94.10   93.20   94.03   22891800      94.03
# 3     2014-07-02   93.87   94.06   93.09   93.48   28420900      93.48
# 4     2014-07-01   93.52   94.07   93.13   93.52   38170200      93.52
# 5     2014-06-30   92.10   93.73   92.09   92.93   49482300      92.93
# 6     2014-06-27   90.82   92.00   90.77   91.98   64006800      91.98
# 7     2014-06-26   90.37   91.05   89.80   90.90   32595800      90.90
# 8     2014-06-25   90.21   90.70   89.65   90.36   36852200      90.36
# 9     2014-06-24   90.75   91.74   90.19   90.28   38988300      90.28
# 10    2014-06-23   91.32   91.62   90.60   90.83   43618200      90.83
# 11    2014-06-20   91.85   92.55   90.90   90.91  100813200      90.91
# ...

# %% [markdown]
# ### Step 4.  Check out the type of the columns

# %%
typeofcolumns=apple.dtypes

# %% [markdown]
# ### Step 5. Transform the Date column as a datetime type

# %%
apple['Date']= pd.to_datetime(apple['Date'])

# %% [markdown]
# ### Step 6.  Set the date as the index

# %%
apple.set_index("Date")
# Out:
#               Open    High     Low   Close     Volume  Adj Close
# Date
# 2014-07-08   96.27   96.80   93.92   95.35   65130000      95.35
# 2014-07-07   94.14   95.99   94.10   95.97   56305400      95.97
# 2014-07-03   93.67   94.10   93.20   94.03   22891800      94.03
# 2014-07-02   93.87   94.06   93.09   93.48   28420900      93.48
# 2014-07-01   93.52   94.07   93.13   93.52   38170200      93.52
# 2014-06-30   92.10   93.73   92.09   92.93   49482300      92.93
# 2014-06-27   90.82   92.00   90.77   91.98   64006800      91.98
# 2014-06-26   90.37   91.05   89.80   90.90   32595800      90.90
# 2014-06-25   90.21   90.70   89.65   90.36   36852200      90.36
# 2014-06-24   90.75   91.74   90.19   90.28   38988300      90.28
# 2014-06-23   91.32   91.62   90.60   90.83   43618200      90.83
# 2014-06-20   91.85   92.55   90.90   90.91  100813200      90.91
# 2014-06-19   92.29   92.30   91.34   91.86   35486400      91.86
# ...

# %% [markdown]
# ### Step 7.  Is there any duplicate dates?

# %%
a=apple['Date'].duplicated().sum()
a
# Out:
# 0

# %% [markdown]
# ### Step 8.  Oops...it seems the index is from the most recent date. Make the first entry the oldest date.

# %%
apple.sort_values('Date').set_index("Date")
# Out:
#               Open    High     Low   Close     Volume  Adj Close
# Date
# 1980-12-12   28.75   28.87   28.75   28.75  117258400       0.45
# 1980-12-15   27.38   27.38   27.25   27.25   43971200       0.42
# 1980-12-16   25.37   25.37   25.25   25.25   26432000       0.39
# 1980-12-17   25.87   26.00   25.87   25.87   21610400       0.40
# 1980-12-18   26.63   26.75   26.63   26.63   18362400       0.41
# 1980-12-19   28.25   28.38   28.25   28.25   12157600       0.44
# 1980-12-22   29.63   29.75   29.63   29.63    9340800       0.46
# 1980-12-23   30.88   31.00   30.88   30.88   11737600       0.48
# 1980-12-24   32.50   32.63   32.50   32.50   12000800       0.51
# 1980-12-26   35.50   35.62   35.50   35.50   13893600       0.55
# 1980-12-29   36.00   36.13   36.00   36.00   23290400       0.56
# 1980-12-30   35.25   35.25   35.12   35.12   17220000       0.55
# 1980-12-31   34.25   34.25   34.13   34.13    8937600       0.53
# ...

# %% [markdown]
# ### Step 9. Get the last business day of each month

# %%
z=pd.date_range(start=apple['Date'].iloc[0],end=apple['Date'].iloc[8464],freq='M')

# %% [markdown]
# ### Step 10.  What is the difference in days between the first day and the oldest

# %%
a=apple.sort_values('Date')
diff=a['Date'][0]-a['Date'][8464]
diff
# Out:
# Timedelta('12261 days 00:00:00')

# %% [markdown]
# ### Step 11.  How many months in the data we have?

# %%
from datetime import datetime, timedelta
from calendar import monthrange
Months=(a['Date'][0].year - a['Date'][8464].year) * 12 +(a['Date'][8464].month - a['Date'][8464].month)
Months
# Out:
# 408

# %% [markdown]
# ### Step 12. Plot the 'Adj Close' value. Set the size of the figure to 13.5 x 9 inches

# %%
import matplotlib.pyplot as plt
apple['Adj Close'].plot(figsize=(13.5,9))

# %% [markdown]
# ### BONUS: Create your own question and answer it.
